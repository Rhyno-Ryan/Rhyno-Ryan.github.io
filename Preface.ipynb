# %% [markdown]
# # Preface
#
# The following work was done with the support of [Dr. Mario Bañuelos](https://www.linkedin.com/in/mario-ba%C3%B1uelos-0199617b/) and [Bethany Hernandez-Torres](https://www.linkedin.com/in/bethany-hernandez-torres-b038b92b6/). In particular, this project was originally thought up by Dr. Bañuelos as a series of workshops to support students attending their first REU in data science. The goal was to give students in the workshops the skills to use Google Colab to visualize data, apply statistical methods to draw inferences about the data, and develop background knowledge of the different kinds of machine learning models.
#
# Bethany then brought this project to life, creating both its name, **Statistical Analysis, Visualization & Inference (S.A.V.I)**, and logo for this project. She, alongside Dr. Banoulos, continues to provide feedback on all aspects of the project from topic choice to the finer details of the code.
#
# S.A.V.I remains as a continuing project to support future students and those willing to learn.
#
# The name for this work was inspired by the word “savi,” which means rain in Mixteco, or Tu’un Sávi (“language of the rain”). Mixteco is one of the most widely spoken indigenous languages in Mexico, primarily in the state of Oaxaca, as well as in Guerrero, Puebla, and among migrant communities in the U.S [1].

# %% [markdown]
# ## Setting the Stage
#
# > Probablity and Statistics is about how we quantify and update our beliefs and deal with uncertainty - Joe Blitzstien
#
# In general, data analysis is about making inferences about some set of data through visualizations, statitical models, and mathematical methoods. Here we devlope each of these skills through generalizing examples seen in the following Google Colab notebooks.
#
# We start by first observing what our data looks like through histograms, plots, and time-series charts. Next we consider the statistical methods used to make inferenecs about our data. Then lastly, we apply models our data using methods such as linear regression.
#
# For clarity sake, before starting any of the notebooks here are some words that are commonly interchangable [2]:
#
# > "independent varibles, predictors, features, and varibles."
#
# > "dependent varibles and reponses."

# %% [markdown]
# Sources:
#
# [1] [What is savi?](https://www.rarelanguage.com/blog/evolution-of-mixteco)
#
# [2] [Introduction to Statistical Learning](https://www.statlearning.com/)
